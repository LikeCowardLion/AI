# %%
from keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.models import Model
from tensorflow.keras.layers import ELU, ReLU, Reshape, Input, Conv1D, MaxPooling1D, AveragePooling1D, Flatten, Dense, Dropout, LSTM, BatchNormalization, ZeroPadding1D, LeakyReLU
from tensorflow.keras.layers import GlobalAveragePooling2D, Conv2D, Activation, Add, MaxPooling2D, AveragePooling2D, ZeroPadding2D, GlobalMaxPooling1D, GlobalMaxPooling2D, GlobalAveragePooling1D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split, LeaveOneOut
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.utils import shuffle
import pandas as pd
import numpy as np
import scipy.stats as stats
import pickle
import matplotlib.pyplot as plt
import glob
import os
import re
import seaborn as sns

# %%
# MinMax 정규화

def standardize_data(df, col, min_value, max_value):
  scaler = MinMaxScaler()
    
  # 표준화할 데이터 준비 (예시로 특정 열만 사용)
  df.reset_index(drop=True, inplace=True)
  data_to_standardize = df.loc[:,[col]]

  # min_value와 max_value를 Series로 변환
  min_series = pd.Series([min_value], index=[len(data_to_standardize)])
  max_series = pd.Series([max_value], index=[len(data_to_standardize) + 1])

  # 최대값, 최솟값 삽입 (Series를 DataFrame에 추가)
  data_to_standardize.loc[len(data_to_standardize)] = min_value
  data_to_standardize.loc[len(data_to_standardize)] = max_value

  # 데이터를 표준화
  standardized_data = scaler.fit_transform(data_to_standardize)

  # 표준화된 데이터를 DataFrame으로 변환
  standardized_df = pd.DataFrame(standardized_data, columns=[col])

  # 원래 데이터에 표준화된 데이터로 업데이트
  df.loc[:, [col]] = standardized_df[[col]].astype(float)

  return df[[col]]

# %%
# standard 정규화

def sstandardize_data(df, col):
  scaler = StandardScaler()
    
  # 표준화할 데이터 준비 (예시로 특정 열만 사용)
  df.reset_index(drop=True, inplace=True)
  data_to_standardize = df.loc[:,[col]]
    
  # 데이터를 표준화
  standardized_data = scaler.fit_transform(data_to_standardize)

  # 표준화된 데이터를 DataFrame으로 변환
  standardized_df = pd.DataFrame(standardized_data, columns=[col])

  # 원래 데이터에 표준화된 데이터로 업데이트
  df.loc[:, [col]] = standardized_df[[col]]

  return df[[col]]

# %%
# Acc_X, Acc_Y, Gyr_Z 추출하는 함수
def extract_data(input_file):
    file = pd.read_csv(input_file)
    file.drop(['Time', 'Acc_Z', ' Gyr_X', ' Gyr_Y'], axis=1, inplace=True)
    file = file.drop(0, axis=0)
    file.reset_index(drop=True, inplace=True)
    file = file.astype(float)
    return file

# %%
# 구간을 자르는 함수
def cut_length(input_file):
    normal_data = input_file.copy()
    
    for col in normal_data.columns:
        if col == "Acc_X":
            normal_data[col] = standardize_data(normal_data, col, -4, 4)
        elif col == "Acc_Y":
            normal_data[col] = standardize_data(normal_data, col, -4, 4)
        else:
            normal_data[col] = standardize_data(normal_data, col, -2000, 2000)
    
    for j in range(1, len(input_file)):
        if abs(float(input_file.iloc[j]['Acc_X'])) > 0.1:
            # print(a ,"해당 구간 : ", len(input_file) - j)
            insert_data = normal_data[j:j+10]
            break
    return insert_data.values

# %%
def plot_histogram(mm):
    # 그래프 크기 설정
    plt.figure(figsize=(15, 5))
    
    # 히스토그램 (Histogram)
    plt.subplot(1, 3, 1)
    sns.histplot(mm, bins=30, kde=True, color='skyblue')
    plt.title('Gyr_Z Histogram')
    
    # 그래프 표시
    plt.tight_layout()
    plt.show()

# %%
def loocv_model(data, result):
    # Leave-One-Out Cross-Validation
    loo = LeaveOneOut()
    mse_scores = []
    mae_scores = []
    average = []
    save_folder = "sbmodel"
    
    fold = 1
    for train_idx, test_idx in loo.split(data):
        X_train, X_test = data[train_idx], data[test_idx]
        y_train, y_test = result[train_idx], result[test_idx]
        
        model = build_resnet_lstm_model()
        optimizer = Adam(learning_rate=0.001)
        model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])
        
        history = model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=0)

        # 저장할 파일 경로 생성
        file_name = f"tf_loocv_resnet_lstm_model_{fold+1}.h5"
        full_path = os.path.join(save_folder, file_name)
    
        # 모델 저장
        model.save(full_path)
        
        y_pred = model.predict(X_test)

        # y_test와 y_pred 차이 출력
        original_y_pred = scaler.inverse_transform(y_pred)
        original_y_test = scaler.inverse_transform(y_test)
        
        mse = mean_squared_error(y_test, y_pred)
        mae = np.mean(np.abs(y_test - y_pred))
        mean = np.abs(original_y_pred - original_y_test)
        
        mse_scores.append(mse)
        mae_scores.append(mae)
        average.append(mean)
        
        print(f'Fold {fold} Test Results:')
        print(f'y_test: {original_y_test.flatten()}')
        print(f'y_pred: {original_y_pred.flatten()}')
        print(f'Difference: {(original_y_test - original_y_pred).flatten()}')
        
        # 모델 저장
        model.save(f"models/fold_{fold}.h5")
        fold += 1
    
    # 결과 출력
    print(f'Average MSE: {np.mean(mse_scores):.4f}')
    print(f'Average MAE: {np.mean(mae_scores):.4f}')
    print(f'Average: {np.mean(average):.4f}')

# %%
# 파일 전부 읽어오기

path = "D:\ㅎㅅㅂ\Puck_data"

file_list = glob.glob(path+'/**')
files = []
labels = []
for i in range(len(file_list)):
    f = glob.glob(file_list[i]+'/**')
    for x in f:
        if x.endswith('.csv'):
            files.append(x)
            matches = re.findall(r'\([^\(\)]*\)', x)
            labels.append(matches)

# %%
# 이상치를 제외한 파일 읽어오기

path = "D:\ㅎㅅㅂ\Puck_data"

file_list = glob.glob(path+'/**')
files = []
labels = []

for i in range(len(file_list)):
    f = glob.glob(file_list[i] + '/**')
    for x in f:
        if x.endswith('.csv'):
            matches = re.findall(r'\([^\(\)]*\)', x)

            # 파일을 읽어서 " Gyr_Z" 값이 1000을 넘는 행이 있는지 확인
            df = pd.read_csv(x)
            if " Gyr_Z" in df.columns:  # 해당 열이 있는지 확인
                if (df[" Gyr_Z"].abs() > 1500).any():
                    print(f"❌ 파일 제외: {x}")  # 제외되는 파일 출력
                    continue  # 해당 파일 건너뛰기
            
            files.append(x)
            labels.append(matches)
# Out:
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250122\SensorData_20250122_160108(99,223,62).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250122\SensorData_20250122_160434(187,362,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250122\SensorData_20250122_160657(14,341,45).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250123\SensorData_20250123_164843(37,514,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250123\SensorData_20250123_164957(-53,223,22).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250123\SensorData_20250123_165222(-134,289,14).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250123\SensorData_20250123_165338(-100,275,14).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250123\SensorData_20250123_165410(-122,218,12).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250123\SensorData_20250123_165941(-100,186,12).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250123\SensorData_20250123_170006(-114,250,13).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250123\SensorData_20250123_171533(-65,152,21).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250123\SensorData_20250123_171957(-59,327,25).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250123\SensorData_20250123_172815(30,141,41).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250123\SensorData_20250123_173312(145,355,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250123\SensorData_20250123_175212(10,467,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_155833(17,267,43).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_160111(3,144,41).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_160647(20,313,44).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_160722(-10,176,31).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_160800(-14,110,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_160859(-3,230,33).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_161052(23,336,45).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_162317(13,372,46).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_162604(88,372,56).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_163620(-123,309,14).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_164306(135,236,63).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_164438(-97,186,12).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_164624(-95,383,16).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_164701(-68,333,25).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_164807(-93,209,14).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_165154(81,284,54).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_165234(-97,310,14).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_165322(-90,467,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_165710(120,367,66).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_165755(-72,393,26).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_165830(12,552,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250206\SensorData_20250206_165947(69,478,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250213\SensorData_20250213_170227(-170,394,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250213\SensorData_20250213_170858(115,288,64).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250213\SensorData_20250213_171000(-18,330,35).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250213\SensorData_20250213_171146(-4,343,35).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250213\SensorData_20250213_171447(-38,195,32).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250213\SensorData_20250213_171608(-24,352,35).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250213\SensorData_20250213_172105(26,434,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250213\SensorData_20250213_172201(-75,353,25).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250213\SensorData_20250213_172237(-51,234,23).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250213\SensorData_20250213_172305(-48,475,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250213\SensorData_20250213_172708(40,232,43).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250213\SensorData_20250213_172746(80,321,55).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250213\SensorData_20250213_173053(-78,307,24).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250218\SensorData_20250218_154053(-46,207,22).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250219\SensorData_20250219_180453(-71,284,24).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250219\SensorData_20250219_180530(143,453,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250219\SensorData_20250219_181354(143,166,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250219\SensorData_20250219_181837(29,450,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250219\SensorData_20250219_181907(143,167,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\250219\SensorData_20250219_183303(-131,171,11).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\251016\SensorData_20250116_163749(-125,196,12).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\251016\SensorData_20250116_163831(-42,174,31).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\Assets\SensorData_20250115_164631(58,405,00).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\Assets\SensorData_20250115_165728(25,190,42).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\Assets\SensorData_20250115_170523(-33,390,36).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\Assets\SensorData_20250115_172448(112,344,65).csv
# ❌ 파일 제외: D:\ㅎㅅㅂ\Puck_data\Assets\SensorData_20250115_172842(-50,405,26).csv

# %%
# 데이터 전처리

data = []
#mmx = []
#mmy = []
#mmz = []

for i in files:
    file = extract_data(i)
    #print(file["Acc_X"].max(), file["Acc_X"].min())
    #mmx.append(file["Acc_X"].max())
    #mmx.append(file["Acc_X"].min())
    #mmy.append(file["Acc_Y"].max())
    #mmy.append(file["Acc_Y"].min())
    #mmz.append(file[" Gyr_Z"].max())
    #mmz.append(file[" Gyr_Z"].min())
    insert_data = cut_length(file)
    data.append(insert_data)
data = np.array(data)

# %%
plot_histogram(mmx)
plot_histogram(mmy)
plot_histogram(mmz)

# %%
# x y 좌표 추출
result = []
for item in labels:
    # 문자열에서 숫자를 추출
    numbers = re.findall(r'-?\d+', item[0])
    # 정수로 변환 후 앞의 두 숫자만 가져와 리스트에 추가
    result.append(list(map(int, numbers[:2])))
result = np.array(result)

# %%
import tensorflow as tf

def residual_block(x, filters):
    shortcut = x  # 원본 입력을 저장 (skip connection)
    
    x = Conv1D(filters, 3, padding="same")(x)
    x = ReLU()(x)
    x = Conv1D(filters, 3, padding="same")(x)
    if shortcut.shape[-1] != filters:
        shortcut = Conv1D(filters, 1, padding="same")(shortcut)
    # Skip connection: 입력을 출력과 더함
    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

# ✅ ResNet + LSTM 모델 구축
def build_resnet_lstm_model(input_shape=(10, 3)):  # (시퀀스 길이, 특징 개수)
    inputs = Input(shape=input_shape)
    
    # CNN 기반 특징 추출
    x = Conv1D(8, 3, padding="same")(inputs)
    x = ReLU()(x)
    
    # Residual Blocks 추가
    x = residual_block(x, 16)
    x = MaxPooling1D()(x)
    
    x = residual_block(x, 32)
    x = MaxPooling1D()(x)
    
    x = residual_block(x, 64)
    x = GlobalMaxPooling1D()(x)
    
    # LSTM 적용
    x = tf.expand_dims(x, axis=1)  # LSTM을 위한 차원 확장 (Batch, 1, Features)
    x = LSTM(128, return_sequences=False)(x)
    
    # Fully Connected Layer
    x = Dense(64)(x)
    outputs = Dense(2)(x)  # (x, y) 좌표 출력
    
    model = Model(inputs, outputs)
    return model

# 모델 생성 및 컴파일
model = build_resnet_lstm_model()
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# 모델 요약 출력
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 10, 3)]      0           []
#
#  conv1d (Conv1D)                (None, 10, 8)        80          ['input_1[0][0]']
#
#  re_lu (ReLU)                   (None, 10, 8)        0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 10, 16)       400         ['re_lu[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 10, 16)       0           ['conv1d_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 10, 16)       784         ['re_lu_1[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 10, 16)       144         ['re_lu[0][0]']
#
#  add (Add)                      (None, 10, 16)       0           ['conv1d_2[0][0]',
#                                                                   'conv1d_3[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 10, 16)       0           ['add[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 5, 16)        0           ['re_lu_2[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 5, 32)        1568        ['max_pooling1d[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 5, 32)        0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 5, 32)        3104        ['re_lu_3[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 5, 32)        544         ['max_pooling1d[0][0]']
#
#  add_1 (Add)                    (None, 5, 32)        0           ['conv1d_5[0][0]',
#                                                                   'conv1d_6[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 5, 32)        0           ['add_1[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 2, 32)       0           ['re_lu_4[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 2, 64)        6208        ['max_pooling1d_1[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 2, 64)        0           ['conv1d_7[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 2, 64)        12352       ['re_lu_5[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 2, 64)        2112        ['max_pooling1d_1[0][0]']
#
#  add_2 (Add)                    (None, 2, 64)        0           ['conv1d_8[0][0]',
#                                                                   'conv1d_9[0][0]']
#
#  re_lu_6 (ReLU)                 (None, 2, 64)        0           ['add_2[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 64)          0           ['re_lu_6[0][0]']
#  xPooling1D)
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 64)        0           ['global_max_pooling1d[0][0]']
#
#  lstm (LSTM)                    (None, 128)          98816       ['tf.expand_dims[0][0]']
#
#  dense (Dense)                  (None, 64)           8256        ['lstm[0][0]']
#
#  dense_1 (Dense)                (None, 2)            130         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 134,498
# Trainable params: 134,498
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def build_resnet_model(input_shape=(5, 3)):
    inputs = Input(shape=input_shape)
    x = Conv1D(8, 3, padding="same")(inputs)
    x = ReLU()(x)
    x = Conv1D(16, 3, padding="same")(x)
    x = ReLU()(x)
    x = MaxPooling1D()(x)
    x = Conv1D(32, 3, padding="same")(x)
    x = ReLU()(x)
    x = MaxPooling1D()(x)
    x = Conv1D(64, 3, padding="same")(x)
    x = ReLU()(x)
    x = GlobalMaxPooling1D()(x)
    x = Dense(128)(x)
    #x = RELU()(x)
    outputs = Dense(2)(x)  # (x, y) 좌표 출력
    
    model = Model(inputs, outputs)
    return model

# 모델 생성 및 컴파일
model = build_resnet_model()
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# 모델 요약 출력
model.summary()
# Out:
# Model: "model_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_45 (InputLayer)       [(None, 5, 3)]            0
#
#  conv1d_162 (Conv1D)         (None, 5, 8)              80
#
#  re_lu_123 (ReLU)            (None, 5, 8)              0
#
#  conv1d_163 (Conv1D)         (None, 5, 16)             400
#
#  re_lu_124 (ReLU)            (None, 5, 16)             0
#
#  max_pooling1d_72 (MaxPoolin  (None, 2, 16)            0
#  g1D)
#
#  conv1d_164 (Conv1D)         (None, 2, 32)             1568
#
#  re_lu_125 (ReLU)            (None, 2, 32)             0
#
#  max_pooling1d_73 (MaxPoolin  (None, 1, 32)            0
#  g1D)
#
#  conv1d_165 (Conv1D)         (None, 1, 64)             6208
#
#  re_lu_126 (ReLU)            (None, 1, 64)             0
#
#  global_max_pooling1d_18 (Gl  (None, 64)               0
#  obalMaxPooling1D)
#
#  dense_77 (Dense)            (None, 128)               8320
#
#  dense_78 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 16,834
# Trainable params: 16,834
# Non-trainable params: 0
# _________________________________________________________________

# %%
original_result = result
scaler = MinMaxScaler()
scaler.fit(result)
standard_result = scaler.transform(result)

# %% [markdown]
# # Train Model

# %%
# train test set 분리
X_train, X_test, y_train, y_test = train_test_split(data, standard_result, test_size=0.2, random_state=777, shuffle=False)

# model 훈련
#es = EarlyStopping(patience=20)
#rlr = ReduceLROnPlateau(factor=0.1, patience=5)
history = model.fit(X_train, y_train, epochs=100, batch_size=1)

# model 저장
path = "path" + str("106")
model.save(path, ".h5")

# model 평가
model.evaluate(X_test, y_test)
predictions = model.predict(X_test)

# 모델 학습 진행 후...
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
# Out:
# Epoch 1/100
# 603/603 [==============================] - 17s 24ms/step - loss: 0.0434 - mae: 0.1691
# Epoch 2/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0294 - mae: 0.1349
# Epoch 3/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0281 - mae: 0.1309
# Epoch 4/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0274 - mae: 0.1292
# Epoch 5/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0269 - mae: 0.1279
# Epoch 6/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0261 - mae: 0.1252
# Epoch 7/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0257 - mae: 0.1262
# Epoch 8/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0260 - mae: 0.1264
# Epoch 9/100
# 603/603 [==============================] - 14s 23ms/step - loss: 0.0258 - mae: 0.1256
# Epoch 10/100
# 603/603 [==============================] - 14s 23ms/step - loss: 0.0256 - mae: 0.1248
# Epoch 11/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0256 - mae: 0.1251
# Epoch 12/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0247 - mae: 0.1224
# Epoch 13/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0253 - mae: 0.1222
# Epoch 14/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0246 - mae: 0.1225
# Epoch 15/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0249 - mae: 0.1227
# Epoch 16/100
# 603/603 [==============================] - 14s 23ms/step - loss: 0.0248 - mae: 0.1212
# Epoch 17/100
# 603/603 [==============================] - 16s 26ms/step - loss: 0.0243 - mae: 0.1209
# Epoch 18/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0241 - mae: 0.1204
# Epoch 19/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0240 - mae: 0.1203
# Epoch 20/100
# 603/603 [==============================] - 15s 26ms/step - loss: 0.0238 - mae: 0.1187
# Epoch 21/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0230 - mae: 0.1170
# Epoch 22/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0239 - mae: 0.1197
# Epoch 23/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0233 - mae: 0.1176
# Epoch 24/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0231 - mae: 0.1162
# Epoch 25/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0235 - mae: 0.1181
# Epoch 26/100
# 603/603 [==============================] - 15s 26ms/step - loss: 0.0231 - mae: 0.1164
# Epoch 27/100
# 603/603 [==============================] - 14s 23ms/step - loss: 0.0225 - mae: 0.1150
# Epoch 28/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0227 - mae: 0.1156
# Epoch 29/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0227 - mae: 0.1161
# Epoch 30/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0228 - mae: 0.1156
# Epoch 31/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0225 - mae: 0.1156
# Epoch 32/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0219 - mae: 0.1140
# Epoch 33/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0225 - mae: 0.1136
# Epoch 34/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0223 - mae: 0.1148
# Epoch 35/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0218 - mae: 0.1131
# Epoch 36/100
# 603/603 [==============================] - 14s 23ms/step - loss: 0.0218 - mae: 0.1130
# Epoch 37/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0217 - mae: 0.1129
# Epoch 38/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0214 - mae: 0.1116
# Epoch 39/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0212 - mae: 0.1112
# Epoch 40/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0204 - mae: 0.1093
# Epoch 41/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0215 - mae: 0.1112
# Epoch 42/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0203 - mae: 0.1091
# Epoch 43/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0210 - mae: 0.1114
# Epoch 44/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0204 - mae: 0.1088
# Epoch 45/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0200 - mae: 0.1083
# Epoch 46/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0203 - mae: 0.1088
# Epoch 47/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0197 - mae: 0.1070
# Epoch 48/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0201 - mae: 0.1077
# Epoch 49/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0191 - mae: 0.1045
# Epoch 50/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0200 - mae: 0.1078
# Epoch 51/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0190 - mae: 0.1048
# Epoch 52/100
# 603/603 [==============================] - 15s 26ms/step - loss: 0.0189 - mae: 0.1044
# Epoch 53/100
# 603/603 [==============================] - 14s 23ms/step - loss: 0.0187 - mae: 0.1033
# Epoch 54/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0180 - mae: 0.1022
# Epoch 55/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0180 - mae: 0.1008
# Epoch 56/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0187 - mae: 0.1034
# Epoch 57/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0180 - mae: 0.1023
# Epoch 58/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0183 - mae: 0.1033
# Epoch 59/100
# 603/603 [==============================] - 14s 23ms/step - loss: 0.0181 - mae: 0.1019
# Epoch 60/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0167 - mae: 0.0978
# Epoch 61/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0173 - mae: 0.0991
# Epoch 62/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0170 - mae: 0.0976
# Epoch 63/100
# 603/603 [==============================] - 14s 22ms/step - loss: 0.0161 - mae: 0.0963
# Epoch 64/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0158 - mae: 0.0967
# Epoch 65/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0159 - mae: 0.0956
# Epoch 66/100
# 603/603 [==============================] - 14s 23ms/step - loss: 0.0149 - mae: 0.0940
# Epoch 67/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0148 - mae: 0.0926
# Epoch 68/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0144 - mae: 0.0925
# Epoch 69/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0136 - mae: 0.0899
# Epoch 70/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0151 - mae: 0.0929
# Epoch 71/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0140 - mae: 0.0899
# Epoch 72/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0132 - mae: 0.0876
# Epoch 73/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0134 - mae: 0.0874
# Epoch 74/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0130 - mae: 0.0872
# Epoch 75/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0125 - mae: 0.0853
# Epoch 76/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0126 - mae: 0.0858
# Epoch 77/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0123 - mae: 0.0843
# Epoch 78/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0120 - mae: 0.0831
# Epoch 79/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0124 - mae: 0.0849
# Epoch 80/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0121 - mae: 0.0830
# Epoch 81/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0109 - mae: 0.0808
# Epoch 82/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0110 - mae: 0.0800
# Epoch 83/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0114 - mae: 0.0826
# Epoch 84/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0138 - mae: 0.0888
# Epoch 85/100
# 603/603 [==============================] - 16s 26ms/step - loss: 0.0103 - mae: 0.0772
# Epoch 86/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0095 - mae: 0.0742
# Epoch 87/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0088 - mae: 0.0716
# Epoch 88/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0124 - mae: 0.0828
# Epoch 89/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0095 - mae: 0.0746
# Epoch 90/100
# 603/603 [==============================] - 14s 23ms/step - loss: 0.0086 - mae: 0.0709
# Epoch 91/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0097 - mae: 0.0744
# Epoch 92/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0106 - mae: 0.0777
# Epoch 93/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0099 - mae: 0.0754
# Epoch 94/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0083 - mae: 0.0692
# Epoch 95/100
# 603/603 [==============================] - 13s 22ms/step - loss: 0.0093 - mae: 0.0725
# Epoch 96/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0091 - mae: 0.0733
# Epoch 97/100
# 603/603 [==============================] - 14s 24ms/step - loss: 0.0077 - mae: 0.0676
# Epoch 98/100
# 603/603 [==============================] - 15s 24ms/step - loss: 0.0073 - mae: 0.0644
# Epoch 99/100
# 603/603 [==============================] - 14s 23ms/step - loss: 0.0100 - mae: 0.0753
# Epoch 100/100
# 603/603 [==============================] - 15s 25ms/step - loss: 0.0071 - mae: 0.0643
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: path106\assets
# INFO:tensorflow:Assets written to: path106\assets
# 5/5 [==============================] - 1s 4ms/step - loss: 0.0405 - mae: 0.1534
# 5/5 [==============================] - 1s 3ms/step

# %% [markdown]
# # LOOCV Model

# %%
loocv_model(data, standard_result)
# Out:
# 1/1 [==============================] - 1s 702ms/step
# Fold 1 Test Results:
# y_test: [ 10. 161.]
# y_pred: [ 49.32257 224.70244]
# Difference: [-39.3225708  -63.70243835]
# 1/1 [==============================] - 1s 692ms/step
# Fold 2 Test Results:
# y_test: [ 52. 189.]
# y_pred: [ 77.40155 226.80753]
# Difference: [-25.40155029 -37.80752563]
# 1/1 [==============================] - 1s 1s/step
# Fold 3 Test Results:
# y_test: [ 99. 290.]
# y_pred: [110.392555 272.36465 ]
# Difference: [-11.39255524  17.63534546]
# 1/1 [==============================] - 1s 625ms/step
# Fold 4 Test Results:
# y_test: [-63. 232.]
# y_pred: [-47.270916 219.08057 ]
# Difference: [-15.72908401  12.91943359]
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000029AFF7EB400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 712ms/step
# Fold 5 Test Results:
# y_test: [ 83. 282.]
# y_pred: [134.96552 240.83899]
# Difference: [-51.96551514  41.16101074]
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000029AFF7E8430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 550ms/step
# Fold 6 Test Results:
# y_test: [  2. 314.]
# y_pred: [ -2.0344222 237.28554  ]
# Difference: [ 4.03442216 76.71446228]
# 1/1 [==============================] - 1s 972ms/step
# Fold 7 Test Results:
# y_test: [ -6. 374.]
# y_pred: [-115.08025  269.58063]
# Difference: [109.0802536  104.41937256]
# 1/1 [==============================] - 1s 1s/step
# Fold 8 Test Results:
# y_test: [ 65. 445.]
# y_pred: [ 71.133575 362.54016 ]
# Difference: [-6.13357544 82.45983887]
# 1/1 [==============================] - 1s 603ms/step
# Fold 9 Test Results:
# y_test: [ 88. 306.]
# y_pred: [ 67.643486 257.96506 ]
# Difference: [20.35651398 48.03494263]
# 1/1 [==============================] - 1s 689ms/step
# Fold 10 Test Results:
# y_test: [-73. 324.]
# y_pred: [-114.43127  200.333  ]
# Difference: [ 41.43126678 123.66700745]
# 1/1 [==============================] - 1s 663ms/step
# Fold 11 Test Results:
# y_test: [-62. 289.]
# y_pred: [-103.19519  255.82227]
# Difference: [41.19519043 33.17773438]
# 1/1 [==============================] - 1s 577ms/step
# Fold 12 Test Results:
# y_test: [ 93. 252.]
# y_pred: [ 96.27536 235.86218]
# Difference: [-3.27536011 16.13781738]
# 1/1 [==============================] - 1s 585ms/step
# Fold 13 Test Results:
# y_test: [-115.  158.]
# y_pred: [-96.3333 218.4256]
# Difference: [-18.66670227 -60.42559814]
# 1/1 [==============================] - 1s 614ms/step
# Fold 14 Test Results:
# y_test: [-71. 340.]
# y_pred: [-58.772488 246.41557 ]
# Difference: [-12.22751236  93.58442688]
# 1/1 [==============================] - 1s 932ms/step
# Fold 15 Test Results:
# y_test: [ 28. 356.]
# y_pred: [ 85.7678  261.48676]
# Difference: [-57.76779938  94.51324463]
# 1/1 [==============================] - 1s 886ms/step
# Fold 16 Test Results:
# y_test: [-32. 274.]
# y_pred: [-43.225376 255.15608 ]
# Difference: [11.22537613 18.84391785]
# 1/1 [==============================] - 1s 845ms/step
# Fold 17 Test Results:
# y_test: [ 87. 168.]
# y_pred: [115.70963 214.44424]
# Difference: [-28.70963287 -46.44424438]
# 1/1 [==============================] - 1s 1s/step
# Fold 18 Test Results:
# y_test: [ 95. 377.]
# y_pred: [ 78.26337 286.87585]
# Difference: [16.7366333  90.12414551]
# 1/1 [==============================] - 1s 717ms/step
# Fold 19 Test Results:
# y_test: [ 10. 378.]
# y_pred: [ -4.3556166 260.9602   ]
# Difference: [ 14.35561657 117.03979492]
# 1/1 [==============================] - 1s 680ms/step
# Fold 20 Test Results:
# y_test: [-77. 366.]
# y_pred: [-76.62988 206.17459]
# Difference: [ -0.37011719 159.82540894]
# 1/1 [==============================] - 1s 649ms/step
# Fold 21 Test Results:
# y_test: [ -9. 309.]
# y_pred: [-23.998056 253.03856 ]
# Difference: [14.99805641 55.96144104]
# 1/1 [==============================] - 1s 738ms/step
# Fold 22 Test Results:
# y_test: [ 79. 262.]
# y_pred: [ 66.11009 223.3032 ]
# Difference: [12.88990784 38.6967926 ]
# 1/1 [==============================] - 1s 603ms/step
# Fold 23 Test Results:
# y_test: [-96. 310.]
# y_pred: [-80.18713 238.82697]
# Difference: [-15.81286621  71.17303467]
# 1/1 [==============================] - 1s 947ms/step
# Fold 24 Test Results:
# y_test: [ 17. 269.]
# y_pred: [  8.300417 305.54276 ]
# Difference: [  8.69958305 -36.54275513]
# 1/1 [==============================] - 1s 584ms/step
# Fold 25 Test Results:
# y_test: [-63. 202.]
# y_pred: [-43.64833 220.004  ]
# Difference: [-19.35166931 -18.0039978 ]
# 1/1 [==============================] - 1s 1s/step
# Fold 26 Test Results:
# y_test: [120. 193.]
# y_pred: [ 85.75199 200.67325]
# Difference: [34.24800873 -7.67324829]
# 1/1 [==============================] - 1s 611ms/step
# Fold 27 Test Results:
# y_test: [ -6. 245.]
# y_pred: [-26.437355 245.83208 ]
# Difference: [20.43735504 -0.83207703]
# 1/1 [==============================] - 1s 818ms/step
# Fold 28 Test Results:
# y_test: [-24. 273.]
# y_pred: [-79.64773 225.24915]
# Difference: [55.64772797 47.75085449]
# 1/1 [==============================] - 1s 630ms/step
# Fold 29 Test Results:
# y_test: [ 89. 234.]
# y_pred: [ 99.23351 202.16933]
# Difference: [-10.23351288  31.83067322]
# 1/1 [==============================] - 1s 775ms/step
# Fold 30 Test Results:
# y_test: [-84. 235.]
# y_pred: [-84.52783 185.40598]
# Difference: [ 0.52783203 49.59402466]
# 1/1 [==============================] - 1s 561ms/step
# Fold 31 Test Results:
# y_test: [-51. 399.]
# y_pred: [-83.0013  357.80942]
# Difference: [32.001297   41.19058228]
# 1/1 [==============================] - 1s 623ms/step
# Fold 32 Test Results:
# y_test: [ 86. 345.]
# y_pred: [ 56.095543 267.57855 ]
# Difference: [29.90445709 77.42144775]
# 1/1 [==============================] - 1s 863ms/step
# Fold 33 Test Results:
# y_test: [ 98. 240.]
# y_pred: [ 25.648495 137.15984 ]
# Difference: [ 72.35150528 102.84016418]
# 1/1 [==============================] - 1s 1s/step
# Fold 34 Test Results:
# y_test: [-66. 323.]
# y_pred: [-77.23433 266.30157]
# Difference: [11.23432922 56.69842529]
# 1/1 [==============================] - 1s 610ms/step
# Fold 35 Test Results:
# y_test: [-64. 219.]
# y_pred: [-81.65974 222.29483]
# Difference: [17.65973663 -3.29483032]
# 1/1 [==============================] - 1s 807ms/step
# Fold 36 Test Results:
# y_test: [-44. 209.]
# y_pred: [-85.85946 295.98672]
# Difference: [ 41.85945892 -86.98672485]
# 1/1 [==============================] - 1s 689ms/step
# Fold 37 Test Results:
# y_test: [ 73. 205.]
# y_pred: [ 86.77031 429.6544 ]
# Difference: [ -13.77030945 -224.65438843]
# 1/1 [==============================] - 1s 778ms/step
# Fold 38 Test Results:
# y_test: [-76. 241.]
# y_pred: [-75.410324 192.5517  ]
# Difference: [-0.5896759  48.44830322]
# 1/1 [==============================] - 1s 665ms/step
# Fold 39 Test Results:
# y_test: [ 50. 289.]
# y_pred: [ 76.11137 374.8484 ]
# Difference: [-26.11136627 -85.84838867]
# 1/1 [==============================] - 1s 541ms/step
# Fold 40 Test Results:
# y_test: [-32. 304.]
# y_pred: [-71.286804 260.11716 ]
# Difference: [39.2868042  43.88284302]
# 1/1 [==============================] - 1s 537ms/step
# Fold 41 Test Results:
# y_test: [-63. 236.]
# y_pred: [-94.38832 231.9155 ]
# Difference: [31.38832092  4.08450317]
# 1/1 [==============================] - 1s 649ms/step
# Fold 42 Test Results:
# y_test: [ -9. 395.]
# y_pred: [ 14.216329 280.82944 ]
# Difference: [-23.21632862 114.17056274]
# 1/1 [==============================] - 1s 582ms/step
# Fold 43 Test Results:
# y_test: [ 87. 345.]
# y_pred: [ 34.22153 106.58403]
# Difference: [ 52.77846909 238.41596985]
# 1/1 [==============================] - 1s 568ms/step
# Fold 44 Test Results:
# y_test: [-22. 162.]
# y_pred: [-20.682987 279.7545  ]
# Difference: [  -1.31701279 -117.75448608]
# 1/1 [==============================] - 1s 555ms/step
# Fold 45 Test Results:
# y_test: [ 87. 316.]
# y_pred: [ 64.18018 308.17838]
# Difference: [22.81981659  7.82162476]
# 1/1 [==============================] - 1s 771ms/step
# Fold 46 Test Results:
# y_test: [ 29. 277.]
# y_pred: [ 86.76309 269.1106 ]
# Difference: [-57.76309204   7.8894043 ]
# 1/1 [==============================] - 1s 579ms/step
# Fold 47 Test Results:
# y_test: [ 75. 241.]
# y_pred: [ 85.78475 315.54858]
# Difference: [-10.78475189 -74.54858398]
# 1/1 [==============================] - 1s 871ms/step
# Fold 48 Test Results:
# y_test: [-43. 189.]
# y_pred: [-95.80999 281.25406]
# Difference: [ 52.80998993 -92.25405884]
# 1/1 [==============================] - 1s 970ms/step
# Fold 49 Test Results:
# y_test: [-25. 205.]
# y_pred: [-91.29644 276.70682]
# Difference: [ 66.29644012 -71.70681763]
# 1/1 [==============================] - 1s 795ms/step
# Fold 50 Test Results:
# y_test: [-87. 376.]
# y_pred: [-70.26788 299.72983]
# Difference: [-16.7321167   76.27017212]
# 1/1 [==============================] - 1s 834ms/step
# Fold 51 Test Results:
# y_test: [ 32. 220.]
# y_pred: [ 52.44289 265.18442]
# Difference: [-20.44289017 -45.18441772]
# 1/1 [==============================] - 1s 723ms/step
# Fold 52 Test Results:
# y_test: [-23. 275.]
# y_pred: [-68.0953  190.12129]
# Difference: [45.09529877 84.87870789]
# 1/1 [==============================] - 1s 1s/step
# Fold 53 Test Results:
# y_test: [120. 289.]
# y_pred: [114.3249 306.4455]
# Difference: [  5.67510223 -17.44549561]
# 1/1 [==============================] - 1s 825ms/step
# Fold 54 Test Results:
# y_test: [-35. 342.]
# y_pred: [-97.42203 397.1429 ]
# Difference: [ 62.42202759 -55.14291382]
# 1/1 [==============================] - 1s 1s/step
# Fold 55 Test Results:
# y_test: [-39. 178.]
# y_pred: [-11.029569 216.86243 ]
# Difference: [-27.97043133 -38.86242676]
# 1/1 [==============================] - 1s 1s/step
# Fold 56 Test Results:
# y_test: [-81. 335.]
# y_pred: [-86.75219 296.699  ]
# Difference: [ 5.75218964 38.30099487]
# 1/1 [==============================] - 1s 1s/step
# Fold 57 Test Results:
# y_test: [113. 207.]
# y_pred: [ 43.562843 228.95644 ]
# Difference: [ 69.43715668 -21.95643616]
# 1/1 [==============================] - 1s 1s/step
# Fold 58 Test Results:
# y_test: [167. 226.]
# y_pred: [ 31.22606 300.39075]
# Difference: [135.77393913 -74.39074707]
# 1/1 [==============================] - 1s 1s/step
# Fold 59 Test Results:
# y_test: [ 67. 366.]
# y_pred: [126.1798  351.54816]
# Difference: [-59.17980194  14.45184326]
# 1/1 [==============================] - 1s 1s/step
# Fold 60 Test Results:
# y_test: [ 48. 260.]
# y_pred: [ 42.358818 248.6862  ]
# Difference: [ 5.64118195 11.313797  ]
# 1/1 [==============================] - 1s 874ms/step
# Fold 61 Test Results:
# y_test: [ 49. 311.]
# y_pred: [ 93.266106 332.4213  ]
# Difference: [-44.26610565 -21.42129517]
# 1/1 [==============================] - 1s 789ms/step
# Fold 62 Test Results:
# y_test: [-132.  186.]
# y_pred: [-67.58707 296.2527 ]
# Difference: [ -64.41293335 -110.25268555]

# %%
# predictions을 정규화 전 상태로
original_labels = scaler.inverse_transform(predictions)
original_labels
# Out:
# array([[ -17.57476   ,  330.0709    ],
#        [  42.17784   ,  233.9589    ],
#        [  89.15209   ,  231.87138   ],
#        [ -44.122185  ,  263.83554   ],
#        [  -6.796834  ,  417.7947    ],
#        [ -51.241978  ,  263.1197    ],
#        [ -87.47588   ,  395.1026    ],
#        [ 107.65481   ,  313.5536    ],
#        [ -40.644012  ,  330.8838    ],
#        [  58.333286  ,  208.64908   ],
#        [ -29.038717  ,  289.01663   ],
#        [   3.0885434 ,  298.3957    ],
#        [ -69.06736   ,  205.68391   ],
#        [-104.74955   ,  276.17468   ],
#        [ 144.6278    ,  348.6861    ],
#        [   4.1566124 ,  342.5004    ],
#        [  76.287056  ,  218.93184   ],
#        [  58.899296  ,  198.23232   ],
#        [ 118.69098   ,  345.8552    ],
#        [  84.91745   ,  284.6695    ],
#        [ -86.573265  ,  218.1446    ],
#        [ -69.11993   ,  337.43384   ],
#        [ -70.15543   ,  322.80258   ],
#        [-104.46205   ,  334.3072    ],
#        [ 104.8015    ,  410.92215   ],
#        [  57.83774   ,  288.4634    ],
#        [ 102.26538   ,  363.515     ],
#        [ -66.76805   ,  305.71765   ],
#        [ -80.88438   ,  262.9651    ],
#        [ -79.61089   ,  190.60455   ],
#        [ -90.928955  ,  483.0339    ],
#        [  56.57788   ,  222.29364   ],
#        [ 104.39787   ,  447.04428   ],
#        [   1.6785814 ,  371.78165   ],
#        [   0.11779326,  246.13069   ],
#        [ -59.206486  ,  334.0359    ],
#        [  62.01947   ,  321.2768    ],
#        [  -6.986127  ,  278.81805   ],
#        [  62.31084   ,  335.5128    ],
#        [  47.630173  ,  236.17995   ],
#        [  23.739994  ,  169.48712   ],
#        [ -64.5805    ,  386.20053   ],
#        [ -82.47842   ,  186.06117   ],
#        [  49.896595  ,  364.78604   ],
#        [  57.70782   ,  279.20038   ],
#        [  83.58804   ,  361.4954    ],
#        [  61.21716   ,  316.85873   ],
#        [ -35.629387  ,  285.73428   ],
#        [  84.04895   ,  307.38455   ],
#        [ 102.83726   ,  416.3498    ],
#        [ -25.59946   ,  284.74246   ],
#        [  16.687191  ,  417.15588   ],
#        [  50.47134   ,  254.40347   ],
#        [ 148.37881   ,  480.7618    ],
#        [ -71.347435  ,  202.15376   ],
#        [  71.310356  ,  340.37103   ],
#        [ -77.65762   ,  336.75677   ],
#        [ -55.9915    ,  237.119     ],
#        [ -82.01972   ,  206.60794   ],
#        [  93.75636   ,  457.37903   ],
#        [  42.24582   ,  324.29193   ],
#        [  53.29925   ,  298.13593   ],
#        [ -40.633972  ,  348.2229    ],
#        [ 126.39921   ,  256.15216   ],
#        [ -39.38845   ,  421.5173    ],
#        [ -84.70758   ,  441.85266   ],
#        [ 118.18952   ,  329.77728   ],
#        [ 133.92433   ,  295.71417   ],
#        [ -23.258543  ,  380.6373    ],
#        [ -44.599766  ,  366.7829    ],
#        [ -78.184525  ,  227.8856    ],
#        [  51.1719    ,  369.366     ],
#        [  49.4587    ,  244.91676   ],
#        [ -62.47674   ,  294.41827   ],
#        [ -13.396267  ,  386.84567   ],
#        [ -66.05707   ,  327.83575   ],
#        [  93.17003   ,  269.85352   ],
#        [ -32.283794  ,  336.30154   ],
#        [ 101.72101   ,  318.7078    ],
#        [ 102.11695   ,  348.68942   ],
#        [  76.04243   ,  268.2306    ],
#        [  -0.290219  ,  267.45535   ],
#        [ -54.471664  ,  238.06418   ],
#        [ -18.906847  ,  212.96677   ],
#        [ -49.638714  ,  255.40735   ],
#        [ -85.246704  ,  295.09192   ],
#        [  69.76074   ,  278.6901    ],
#        [ -39.30927   ,  376.47995   ],
#        [ 108.83638   ,  307.1897    ],
#        [  52.410156  ,  265.16757   ],
#        [  -2.2066119 ,  200.19627   ],
#        [  -2.5867908 ,  413.12      ],
#        [  92.84009   ,  361.26154   ],
#        [  69.64857   ,  322.50308   ],
#        [  40.35888   ,  175.62047   ],
#        [ -16.653172  ,  378.83102   ],
#        [ -85.30968   ,  188.45984   ],
#        [ -80.87407   ,  271.5035    ],
#        [   3.98394   ,  326.2537    ],
#        [ -18.954908  ,  264.05255   ],
#        [ 100.76917   ,  228.6254    ],
#        [ -37.678333  ,  361.03217   ],
#        [  43.95893   ,  219.61371   ],
#        [ -50.664238  ,  356.7985    ],
#        [ -11.452004  ,  398.97357   ],
#        [ -67.182434  ,  238.79002   ],
#        [ -44.558514  ,  261.45444   ],
#        [ -13.998895  ,  355.81522   ],
#        [ 104.060425  ,  233.85524   ],
#        [ -58.394386  ,  373.11496   ],
#        [   3.925087  ,  298.3018    ],
#        [  35.17769   ,  334.5868    ],
#        [ 110.37868   ,  351.55313   ],
#        [  74.7522    ,  335.07156   ],
#        [ -48.54857   ,  228.59988   ],
#        [ -86.35025   ,  323.34497   ],
#        [  63.11815   ,  195.97194   ],
#        [ -54.21379   ,  447.68942   ],
#        [  67.87098   ,  200.536     ],
#        [ -88.305664  ,  199.37831   ],
#        [  27.798899  ,  273.9769    ],
#        [  12.110993  ,  350.1583    ],
#        [  49.359844  ,  313.48788   ],
#        [  88.922714  ,  438.64645   ],
#        [  83.210594  ,  215.94789   ],
#        [ 104.54581   ,  270.9437    ],
#        [ -65.18104   ,  272.16183   ],
#        [ -37.959175  ,  372.3574    ],
#        [ -34.45619   ,  357.00076   ],
#        [ -88.84741   ,  198.50935   ],
#        [ -90.33735   ,  257.88226   ],
#        [  93.3828    ,  274.1284    ],
#        [ 109.17183   ,  415.64102   ],
#        [ 105.76545   ,  252.39053   ],
#        [ 134.32408   ,  353.07513   ],
#        [  41.90009   ,  205.4164    ],
#        [ -49.553825  ,  382.402     ],
#        [   1.564086  ,  317.45297   ],
#        [  96.799416  ,  302.33734   ],
#        [ -56.14556   ,  370.75665   ],
#        [ -66.71208   ,  255.03952   ],
#        [ -77.54711   ,  261.01712   ],
#        [  84.63477   ,  323.56705   ],
#        [  -9.622503  ,  289.62762   ],
#        [  75.36417   ,  263.93518   ],
#        [  37.0549    ,  204.46622   ],
#        [  38.0198    ,  245.31502   ],
#        [  54.333332  ,  303.6497    ],
#        [ -75.11159   ,  216.97754   ],
#        [ -78.014496  ,  275.52783   ],
#        [ 141.46432   ,  360.25977   ]], dtype=float32)

# %%
# train test set 분리
X_train, X_test, y_train, y_test = train_test_split(data, original_result, test_size=0.2, random_state=777, shuffle=False)
y_test
# Out:
# array([[ -22,  497],
#        [   8,  275],
#        [ 195,  346],
#        [ -19,  253],
#        [  -2,  340],
#        [ -61,  233],
#        [ -51,  111],
#        [ 117,  402],
#        [ -31,  311],
#        [  25,  209],
#        [  -8,  208],
#        [  -3,  217],
#        [  -6,  230],
#        [ -72,  285],
#        [  25,  272],
#        [  15,  255],
#        [  49,  256],
#        [  42,  385],
#        [  80,  295],
#        [  94,  175],
#        [ -93,  312],
#        [-151,  379],
#        [ -14,  222],
#        [ -27,  146],
#        [ 117,  304],
#        [  53,  296],
#        [ 112,  173],
#        [ -22,  320],
#        [-118,  219],
#        [ -93,  371],
#        [ -19,  325],
#        [  42,  391],
#        [  18,  236],
#        [  16,  284],
#        [  15,  272],
#        [ -44,  247],
#        [  12,  150],
#        [ -13,  255],
#        [ 110,  491],
#        [   4,  333],
#        [  75,  259],
#        [-154,  414],
#        [-101,  246],
#        [  -2,  324],
#        [  23,  161],
#        [ 131,  217],
#        [   7,  284],
#        [ -37,  252],
#        [ 133,  321],
#        [ 107,  227],
#        [ -53,  272],
#        [ 102,  404],
#        [  23,  214],
#        [  75,  285],
#        [  -3,  434],
#        [  12,  404],
#        [ -72,  163],
#        [ -80,  345],
#        [ -37,  325],
#        [  76,  325],
#        [  48,  526],
#        [  41,  262],
#        [ -20,  270],
#        [  24,  120],
#        [  -9,  201],
#        [ -21,  221],
#        [  14,  343],
#        [  58,  405],
#        [ -31,  301],
#        [ -55,  586],
#        [ -50,  263],
#        [  12,  196],
#        [  49,  280],
#        [ -63,  293],
#        [  -3,  321],
#        [-109,  196],
#        [  94,  193],
#        [  -4,  125],
#        [  25,  190],
#        [  28,  316],
#        [  12,  163],
#        [ -37,  584],
#        [ -20,  210],
#        [ -38,  487],
#        [ -15,  158],
#        [ -33,  390],
#        [  28,  396],
#        [ -78,  459],
#        [  10,   99],
#        [  -8,  323],
#        [  11,  324],
#        [  35,   78],
#        [ 187,  379],
#        [ 180,  358],
#        [ 143,  282],
#        [ -10,  248],
#        [ -89,  260],
#        [ -58,  220],
#        [  37,  361],
#        [  -9,  232],
#        [  55,   90],
#        [  -8,  100],
#        [  74,  370],
#        [-131,  564],
#        [ 112,  344],
#        [ -31,  250],
#        [ -97,  325],
#        [ -52,  219],
#        [ 163,  190],
#        [-202,  268],
#        [ -50,  405],
#        [  17,  237],
#        [ 102,  350],
#        [  75,  237],
#        [ -65,  317],
#        [ -84,  384],
#        [  86,  481],
#        [ 134,  320],
#        [  99,  401],
#        [ -30,  242],
#        [   4,  403],
#        [ -13,  277],
#        [  46,  473],
#        [  64,  223],
#        [ 122,  384],
#        [  77,  293],
#        [-133,  174],
#        [ -92,  313],
#        [ -89,  212],
#        [-127,  242],
#        [ -41,  267],
#        [ 125,  276],
#        [ 133,  176],
#        [  45,  117],
#        [  12,  222],
#        [  46,  253],
#        [ -24,  181],
#        [ -27,  187],
#        [  10,  118],
#        [ -47,  136],
#        [-132,  402],
#        [ -43,  401],
#        [ 112,  490],
#        [ -12,  367],
#        [  56,  392],
#        [  62,  431],
#        [  34,  299],
#        [ 113,  303],
#        [-130,  331],
#        [ -92,  189],
#        [  95,  308]])

# %%
dd = y_test-original_labels
np.set_printoptions(suppress=True)

# %%
# 절댓값이 100 이상인 값들의 인덱스 찾기
indices = np.where(np.abs(dd[:,0]) >= 100)[0]

if len(indices) > 0:
    max_index = indices[-1]  # 가장 마지막으로 조건을 만족하는 인덱스
    print("절댓값이 100 이상인 값들:", dd[indices])
    print("해당 인덱스까지의 배열:", indices)
else:
    print("절댓값이 100 이상인 값이 없습니다.")
# Out:
# 절댓값이 100 이상인 값들: [[ 105.84790802  114.12861633]
#  [-119.62780762  -76.68609619]
#  [-102.39920807 -136.15216064]
#  [-104.18952179   13.22271729]
#  [ 110.3514328    35.49691772]
#  [ 102.64112091  106.37953186]
#  [ 123.45200443  -54.97357178]
#  [-143.60561371 -105.11495972]
#  [ 188.21379089 -127.68942261]
#  [-122.32408142 -131.07513428]]
# 해당 인덱스까지의 배열: [  2  14  63  66  93  94 104 109 117 134]

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure(figsize=(8,12))

  plt.subplot(3,1,1)
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.plot(hist['epoch'], hist['loss'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_loss'],
           label = 'Val Error')
  plt.legend()

  plt.subplot(3,1,2)
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(hist['epoch'], hist['mae'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'],
           label = 'Val Error')
  plt.legend()
  plt.show()

plot_history(history)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\sb\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'val_loss'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[410], line 26
#      23   plt.legend()
#      24   plt.show()
# ---> 26 plot_history(history)
#
# Cell In[410], line 12, in plot_history(history)
#       9 plt.ylabel('Loss')
#      10 plt.plot(hist['epoch'], hist['loss'],
#      11          label='Train Error')
# ---> 12 plt.plot(hist['epoch'], hist['val_loss'],
#      13          label = 'Val Error')
#      14 plt.legend()
#      16 plt.subplot(3,1,2)
#
# File ~\anaconda3\envs\sb\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\envs\sb\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'val_loss'

# %%
from scipy.stats import skew, kurtosis

def calculate_and_visualize_diff(y_test, original_labels):
    # 데이터프레임 생성
    df = pd.DataFrame()
    df['X_coordinate'] = np.abs(y_test[:, 0] - original_labels[:, 0])
    df['Y_coordinate'] = np.abs(y_test[:, 1] - original_labels[:, 1])
    
    # 통계 값 계산
    stats = {}
    for col in ['X_coordinate', 'Y_coordinate']:
        stats[col] = {
            "mean": df[col].mean(),
            "median": df[col].median(),
            "std": df[col].std(),
            "iqr": np.percentile(df[col], 75) - np.percentile(df[col], 25),
            "min": df[col].min(),
            "max": df[col].max(),
            "skewness": skew(df[col]),
            "kurtosis": kurtosis(df[col])
        }
    
    # 통계 정보 출력
    for col, values in stats.items():
        print(f"Statistics for {col}:")
        for key, value in values.items():
            print(f"  {key.capitalize()}: {value:.2f}")
    
    # 분포도 시각화
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    sns.histplot(df['X_coordinate'], bins=30, kde=True, color='blue', alpha=0.6, ax=axes[0])
    axes[0].axvline(stats['X_coordinate']['mean'], color='red', linestyle='dashed', linewidth=2, label=f'Mean: {stats["X_coordinate"]["mean"]:.2f}')
    axes[0].set_xlabel("X Coordinate")
    axes[0].set_ylabel("Frequency")
    axes[0].set_title("Distribution of Absolute Differences (X Coordinate)")
    axes[0].legend()
    
    sns.histplot(df['Y_coordinate'], bins=30, kde=True, color='orange', alpha=0.6, ax=axes[1])
    axes[1].axvline(stats['Y_coordinate']['mean'], color='red', linestyle='dashed', linewidth=2, label=f'Mean: {stats["Y_coordinate"]["mean"]:.2f}')
    axes[1].set_xlabel("Y Coordinate")
    axes[1].set_ylabel("Frequency")
    axes[1].set_title("Distribution of Absolute Differences (Y Coordinate)")
    axes[1].legend()
    
    plt.tight_layout()
    plt.show()
    
    return stats

# %%
calculate_and_visualize_diff(y_test, original_labels)
# Out:
# Statistics for X_coordinate:
#   Mean: 39.76
#   Median: 33.02
#   Std: 32.88
#   Iqr: 40.56
#   Min: 0.25
#   Max: 188.21
#   Skewness: 1.36
#   Kurtosis: 2.42
# Statistics for Y_coordinate:
#   Mean: 105.98
#   Median: 96.82
#   Std: 74.46
#   Iqr: 110.84
#   Min: 0.35
#   Max: 335.12
#   Skewness: 0.68
#   Kurtosis: -0.09
# {'X_coordinate': {'mean': 39.756029215869525,
#   'median': 33.01606011390686,
#   'std': 32.87959911487182,
#   'iqr': 40.56265074014664,
#   'min': 0.247802734375,
#   'max': 188.2137908935547,
#   'skewness': 1.355484067324263,
#   'kurtosis': 2.4185267390062295},
#  'Y_coordinate': {'mean': 105.983583665052,
#   'median': 96.82005310058594,
#   'std': 74.46088327732281,
#   'iqr': 110.84282684326172,
#   'min': 0.350921630859375,
#   'max': 335.1199951171875,
#   'skewness': 0.6845535135486703,
#   'kurtosis': -0.09208578473785911}}

# %%
# 첫 번째 값의 부호가 다른 경우 필터링
mask = (original_labels[:, 0] * y_test[:, 0]) < 0
filtered_y_pred = original_labels[mask]
filtered_y_test = y_test[mask]

# %%
df = pd.DataFrame({
    "y_pred_0": filtered_y_pred[:, 0],
    "y_test_0": filtered_y_test[:, 0],
    "y_pred_1": filtered_y_pred[:, 1],
    "y_test_1": filtered_y_test[:, 1]
})
df
# Out:
#     y_pred_0  y_test_0    y_pred_1  y_test_1
# 0   3.088543        -3  298.395691       217
# 1  49.896595        -2  364.786041       324
# 2  52.410156        -8  265.167572       323
# 3  -2.206612        11  200.196274       324
# 4  -2.586791        35  413.119995        78
# 5 -11.452004       112  398.973572       344
# 6   3.925087       -50  298.301788       405
# 7 -54.213791       134  447.689423       320
# 8  12.110993       -13  350.158295       277
# 9   1.564086       -27  317.452972       187

# %%
# 파일 전부 읽어오기

path = "D:\ㅎㅅㅂ\Puck_data"

file_list = glob.glob(path+'/**')
files = []
labels = []
for i in range(len(file_list)):
    f = glob.glob(file_list[i]+'/**')
    for x in f:
        if x.endswith('.csv'):
            files.append(x)
            matches = re.findall(r'\([^\(\)]*\)', x)
            labels.append(matches)

# %%
# 데이터 전처리

data = []
#mmx = []
#mmy = []
#mmz = []

for i in files:
    file = extract_data(i)
    #print(file["Acc_X"].max(), file["Acc_X"].min())
    #mmx.append(file["Acc_X"].max())
    #mmx.append(file["Acc_X"].min())
    #mmy.append(file["Acc_Y"].max())
    #mmy.append(file["Acc_Y"].min())
    #mmz.append(file[" Gyr_Z"].max())
    #mmz.append(file[" Gyr_Z"].min())
    insert_data = cut_length(file)
    data.append(insert_data)
data = np.array(data)

# %%
# x y 좌표 추출
result = []
for item in labels:
    # 문자열에서 숫자를 추출
    numbers = re.findall(r'-?\d+', item[0])
    # 정수로 변환 후 앞의 두 숫자만 가져와 리스트에 추가
    result.append(list(map(int, numbers[-1])))
result = np.array(result)
